# %%
import math
import numpy as np
import emoji
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from ipywidgets import Layout, interact, IntSlider,Label, HBox
import ipywidgets as widgets
import os,sys,h5py
from pathlib import Path
import runraptor,rapplot
# %matplotlib inline

# %% [markdown]
# #### Get the data

# %%
# %%bash
# wget https://astro.ru.nl/~jordyd/data2000.dat

# %% [markdown]
# #### Put in the inputs

# %%
data = runraptor.pythonraptor(image_width=200,image_height=200)
slider = data.makeslider()

# %%
writef = data.writefile()

# %%
# %%bash
# ./RAPTOR model.in data2000.dat 10
# Out:
# Using model parameter file model.in
# __________    _____ _____________________________ __________
# \______   \  /  _  \\______   \__    ___/\_____  \\______   \
#  |       _/ /  /_\  \|     ___/ |    |    /   |   \|       _/
#  |    |   \/    |    \    |     |    |   /    |    \    |   \
#  |____|_  /\____|__  /____|     |____|   \_______  /____|_  /
#         \/         \/                            \/       \/
#
# Running RAPTOR v1.0 in polarized mode!
#
# Initializing...
#
# Model parameters:
#
# MBH 		= 3.701e+09 Msun
# DISTANCE 	= 2572 kpc
# M_UNIT 		= 2.739e+25 grams
# R_LOW 		= 1
# R_HIGH 		= 1
# INCLINATION 	= 9 deg
# METRIC 		= MKS BHAC
#
# Observer parameters:
#
# IMG_WIDTH 	= 200
# IMG_HEIGHT 	= 200
# CAM_SIZE_X 	= 20 GM/c2
# CAM_SIZE_Y 	= 20 GM/c2
# FREQS_PER_DEC 	= 1.000000
# FREQ_MIN 	= 2.3e+11 Hz
# STEPSIZE 	= 0.05
#
# Starting read in of BHAC GRMHD data...
#
# Successfully opened data2000.dat.
#
# Reading...Done
#
# Number of frequencies to compute: 1
# ...

# %% [markdown]
# ### Plot the Data

# %%
p = data.plot(10)
plt.show()
# Out:
# Reading keys from:  output/img_data_10.h5
# ['I2.300000e+11', 'Q2.300000e+11', 'U2.300000e+11', 'V2.300000e+11', 'alpha', 'beta', 'tau2.300000e+11', 'tauF2.300000e+11']
# Reading in:  output/img_data_10.h5
# 8
